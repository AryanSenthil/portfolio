# %% [markdown]
# <div style="text-align: center;">
#   <img src="images/cv-1.png" alt="CV Page 1">
# </div>
#
# <div style="text-align: center;">
#   <img src="images/cv-2.png" alt="CV Page 2">
# </div>
